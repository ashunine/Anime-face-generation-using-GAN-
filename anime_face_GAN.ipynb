# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl

# %matplotlib inline

# %%
import torch
from torchvision import datasets, transforms
import os
os.getcwd()
# Out:
# 'C:\\Users\\ashu\\Desktop\\neural n'

# %%
def get_dataloader(batch_size, image_size, data_dir='anime/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    transform = transforms.Compose([transforms.Resize(image_size),transforms.CenterCrop(image_size),transforms.ToTensor()])
  
    dataset = datasets.ImageFolder(data_dir,transform = transform)
    
    dataloader = torch.utils.data.DataLoader(dataset = dataset,batch_size = batch_size,shuffle = True)
    return dataloader
# Define function hyperparameters
batch_size = 256
img_size = 32
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %%
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels
# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %%
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x*(max-min) + min
    return x

# %%
import torch.nn as nn
import torch.nn.functional as F
def conv(input_c,output,kernel_size,stride = 2,padding  = 1, batch_norm = True):
    layers =[]
    con = nn.Conv2d(input_c,output,kernel_size,stride,padding,bias = False)
    layers.append(con)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(output))
    
    return nn.Sequential(*layers)
class Discriminator(nn.Module):
    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        #complete init function
        super(Discriminator, self).__init__()
        self.conv_dim = conv_dim
        self.layer_1 = conv(3,conv_dim,4,batch_norm = False) #16
        self.layer_2 = conv(conv_dim,conv_dim*2,4) #8
        self.layer_3 = conv(conv_dim*2,conv_dim*4,4) #4
        self.fc = nn.Linear(conv_dim*4*4*4,1)
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = F.leaky_relu(self.layer_1(x))
        x = F.leaky_relu(self.layer_2(x))
        x = F.leaky_relu(self.layer_3(x))
        x = x.view(-1,self.conv_dim*4*4*4)
        x = self.fc(x)
        return x

# %%
def deconv(input_c,output,kernel_size,stride = 2, padding =1, batch_norm = True):
    layers = []
    decon = nn.ConvTranspose2d(input_c,output,kernel_size,stride,padding,bias = False)
    layers.append(decon)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(output))
    return nn.Sequential(*layers)
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        # complete init function
        self.conv_dim = conv_dim
        self.fc = nn.Linear(z_size,conv_dim*8*2*2)
        self.layer_1 = deconv(conv_dim*8,conv_dim*4,4) #4
        self.layer_2 = deconv(conv_dim*4,conv_dim*2,4) #8
        self.layer_3 = deconv(conv_dim*2,conv_dim,4) #16
        self.layer_4 = deconv(conv_dim,3,4,batch_norm = False) #32
        
        
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        x = x.view(-1,self.conv_dim*8,2,2) #(batch_size,depth,width,height)
        x = F.relu(self.layer_1(x))
        x = F.relu(self.layer_2(x))
        x = F.relu(self.layer_3(x))
        x = torch.tanh(self.layer_4(x))
        return x

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    if hasattr(m,'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        
        m.weight.data.normal_(0.0,0.02)
    
        if hasattr(m,'bias') and m.bias is not None:
            m.bias.data.zero_()

# %%
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)
# initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)
    print(D)
    print()
    print(G)
    
    return D, G
   
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (layer_1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (layer_2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer_3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=4096, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (layer_1): Sequential(
#     (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer_2): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer_3): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (layer_4): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size)
    #if train_on_gpu:
     #   labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(),labels)
    return loss
def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    #if train_on_gpu:
     #   labels = labels.cuda()
    criterion =  nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(),labels)
    return loss

# %%
import torch.optim as optim
# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(),lr = .0002, betas = [0.5,0.999])
g_optimizer = optim.Adam(G.parameters(),lr = .0002, betas = [0.5,0.999])

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    #if train_on_gpu:
     #   D.cuda()
      #  G.cuda()
# keep track of loss and generated, "fake" samples
    samples = []
    losses = []
# Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    #if train_on_gpu:
     #   fixed_z = fixed_z.cuda()
# epoch training loop
    for epoch in range(n_epochs):
# batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):
            batch_size = real_images.size(0)
            real_images = scale(real_images)
            #if train_on_gpu:
             #   real_images = real_images.cuda()
          
            # 1. Train the discriminator on real and fake ima.ges
            d_optimizer.zero_grad()
            d_out_real = D(real_images)
            z = np.random.uniform(-1,1,size = (batch_size,z_size))
            z = torch.from_numpy(z).float()
            #if train_on_gpu:
             #   z = z.cuda()
            d_loss = real_loss(d_out_real) + fake_loss(D(G(z)))
            d_loss.backward()
            d_optimizer.step()
            # 2. Train the generator with an adversarial loss
            G.train()
            g_optimizer.zero_grad()
            z = np.random.uniform(-1,1,size = (batch_size,z_size))
            z = torch.from_numpy(z).float()
            #if train_on_gpu:
             #   z = z.cuda()
            g_loss = real_loss(D(G(z)))
            g_loss.backward()
            g_optimizer.step()
            
            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))
## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode
# Save training generator samples
    with open('train_samples1.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses
    
    
# set number of epochs 
n_epochs = 40
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   40] | d_loss: 1.8816 | g_loss: 1.2219
# Epoch [    1/   40] | d_loss: 0.2524 | g_loss: 4.5735
# Epoch [    1/   40] | d_loss: 0.4233 | g_loss: 3.4464
# Epoch [    1/   40] | d_loss: 0.7453 | g_loss: 2.9813
# Epoch [    1/   40] | d_loss: 0.9034 | g_loss: 2.2993
# Epoch [    1/   40] | d_loss: 1.0455 | g_loss: 1.7301
# Epoch [    2/   40] | d_loss: 0.8993 | g_loss: 2.9768
# Epoch [    2/   40] | d_loss: 0.6863 | g_loss: 3.2880
# Epoch [    2/   40] | d_loss: 0.5644 | g_loss: 2.9988
# Epoch [    2/   40] | d_loss: 0.7291 | g_loss: 2.3363
# Epoch [    2/   40] | d_loss: 0.8112 | g_loss: 2.0202
# Epoch [    2/   40] | d_loss: 0.8207 | g_loss: 2.7114
# Epoch [    3/   40] | d_loss: 0.8082 | g_loss: 1.3167
# Epoch [    3/   40] | d_loss: 0.8013 | g_loss: 2.5982
# Epoch [    3/   40] | d_loss: 0.8877 | g_loss: 2.4100
# Epoch [    3/   40] | d_loss: 0.8687 | g_loss: 2.0432
# Epoch [    3/   40] | d_loss: 1.1026 | g_loss: 3.4287
# Epoch [    3/   40] | d_loss: 0.7809 | g_loss: 1.9770
# Epoch [    4/   40] | d_loss: 0.9922 | g_loss: 2.2465
# Epoch [    4/   40] | d_loss: 1.1169 | g_loss: 1.0642
# Epoch [    4/   40] | d_loss: 0.9000 | g_loss: 1.2667
# Epoch [    4/   40] | d_loss: 0.7304 | g_loss: 2.3125
# Epoch [    4/   40] | d_loss: 0.7744 | g_loss: 1.4114
# Epoch [    4/   40] | d_loss: 0.7099 | g_loss: 2.2150
# Epoch [    5/   40] | d_loss: 0.8205 | g_loss: 2.2903
# Epoch [    5/   40] | d_loss: 1.1751 | g_loss: 4.1027
# Epoch [    5/   40] | d_loss: 0.7265 | g_loss: 2.2046
# Epoch [    5/   40] | d_loss: 0.7249 | g_loss: 1.9709
# Epoch [    5/   40] | d_loss: 0.9076 | g_loss: 1.1870
# Epoch [    5/   40] | d_loss: 0.7860 | g_loss: 1.9124
# Epoch [    6/   40] | d_loss: 0.8536 | g_loss: 1.8964
# Epoch [    6/   40] | d_loss: 0.8394 | g_loss: 2.2155
# Epoch [    6/   40] | d_loss: 0.7741 | g_loss: 2.3264
# Epoch [    6/   40] | d_loss: 0.7282 | g_loss: 1.6874
# Epoch [    6/   40] | d_loss: 0.7694 | g_loss: 1.7940
# Epoch [    6/   40] | d_loss: 0.7324 | g_loss: 1.6680
# Epoch [    7/   40] | d_loss: 0.9358 | g_loss: 1.5661
# Epoch [    7/   40] | d_loss: 0.8385 | g_loss: 1.4837
# Epoch [    7/   40] | d_loss: 0.7764 | g_loss: 1.8447
# Epoch [    7/   40] | d_loss: 0.7699 | g_loss: 1.5744
# Epoch [    7/   40] | d_loss: 0.7778 | g_loss: 2.2787
# Epoch [    7/   40] | d_loss: 0.8388 | g_loss: 2.4835
# Epoch [    8/   40] | d_loss: 0.8545 | g_loss: 1.7625
# Epoch [    8/   40] | d_loss: 0.8080 | g_loss: 1.8110
# Epoch [    8/   40] | d_loss: 0.7645 | g_loss: 1.3606
# Epoch [    8/   40] | d_loss: 0.7817 | g_loss: 1.8865
# Epoch [    8/   40] | d_loss: 0.7084 | g_loss: 2.0520
# Epoch [    8/   40] | d_loss: 0.8480 | g_loss: 1.3678
# Epoch [    9/   40] | d_loss: 0.8787 | g_loss: 2.3844
# Epoch [    9/   40] | d_loss: 0.8804 | g_loss: 2.1912
# Epoch [    9/   40] | d_loss: 0.8767 | g_loss: 1.4675
# Epoch [    9/   40] | d_loss: 0.8287 | g_loss: 2.1665
# Epoch [    9/   40] | d_loss: 0.9388 | g_loss: 2.3721
# Epoch [    9/   40] | d_loss: 0.7656 | g_loss: 1.7485
# Epoch [   10/   40] | d_loss: 1.0418 | g_loss: 3.6450
# Epoch [   10/   40] | d_loss: 0.9358 | g_loss: 1.9555
# Epoch [   10/   40] | d_loss: 1.0135 | g_loss: 1.4710
# Epoch [   10/   40] | d_loss: 0.8723 | g_loss: 1.3764
# Epoch [   10/   40] | d_loss: 0.7707 | g_loss: 1.7140
# Epoch [   10/   40] | d_loss: 1.0546 | g_loss: 2.8791
# Epoch [   11/   40] | d_loss: 0.9043 | g_loss: 1.2359
# Epoch [   11/   40] | d_loss: 0.9070 | g_loss: 1.1340
# Epoch [   11/   40] | d_loss: 1.0103 | g_loss: 1.1296
# Epoch [   11/   40] | d_loss: 0.8924 | g_loss: 2.0167
# Epoch [   11/   40] | d_loss: 0.8684 | g_loss: 1.1861
# Epoch [   11/   40] | d_loss: 0.9153 | g_loss: 1.7972
# Epoch [   12/   40] | d_loss: 0.9397 | g_loss: 2.4295
# Epoch [   12/   40] | d_loss: 1.2382 | g_loss: 0.5053
# Epoch [   12/   40] | d_loss: 0.7211 | g_loss: 1.5860
# Epoch [   12/   40] | d_loss: 0.9727 | g_loss: 1.7329
# Epoch [   12/   40] | d_loss: 0.7502 | g_loss: 1.9195
# Epoch [   12/   40] | d_loss: 0.8932 | g_loss: 1.2739
# Epoch [   13/   40] | d_loss: 1.0152 | g_loss: 2.7487
# Epoch [   13/   40] | d_loss: 1.0600 | g_loss: 2.1208
# Epoch [   13/   40] | d_loss: 1.0221 | g_loss: 2.5875
# Epoch [   13/   40] | d_loss: 0.7777 | g_loss: 1.6149
# Epoch [   13/   40] | d_loss: 0.9979 | g_loss: 0.9222
# Epoch [   13/   40] | d_loss: 0.8486 | g_loss: 1.7898
# Epoch [   14/   40] | d_loss: 0.8665 | g_loss: 2.0635
# Epoch [   14/   40] | d_loss: 0.9146 | g_loss: 1.4135
# Epoch [   14/   40] | d_loss: 0.8381 | g_loss: 1.9674
# Epoch [   14/   40] | d_loss: 0.8739 | g_loss: 1.3815
# Epoch [   14/   40] | d_loss: 0.7882 | g_loss: 1.8353
# Epoch [   14/   40] | d_loss: 0.8711 | g_loss: 2.0039
# Epoch [   15/   40] | d_loss: 0.8377 | g_loss: 1.8954
# Epoch [   15/   40] | d_loss: 0.9349 | g_loss: 2.1523
# Epoch [   15/   40] | d_loss: 0.8806 | g_loss: 1.5595
# Epoch [   15/   40] | d_loss: 0.8481 | g_loss: 2.1157
# Epoch [   15/   40] | d_loss: 1.4509 | g_loss: 1.1601
# Epoch [   15/   40] | d_loss: 0.9650 | g_loss: 2.3037
# Epoch [   16/   40] | d_loss: 0.8526 | g_loss: 2.6361
# Epoch [   16/   40] | d_loss: 1.4362 | g_loss: 0.3587
# Epoch [   16/   40] | d_loss: 0.8427 | g_loss: 1.6759
# Epoch [   16/   40] | d_loss: 0.7887 | g_loss: 1.8665
# Epoch [   16/   40] | d_loss: 0.7985 | g_loss: 1.6618
# Epoch [   16/   40] | d_loss: 0.7415 | g_loss: 1.7848
# Epoch [   17/   40] | d_loss: 0.8410 | g_loss: 1.1831
# Epoch [   17/   40] | d_loss: 0.8745 | g_loss: 1.9016
# Epoch [   17/   40] | d_loss: 0.9080 | g_loss: 2.0670
# Epoch [   17/   40] | d_loss: 0.8527 | g_loss: 1.4938
# Epoch [   17/   40] | d_loss: 1.1592 | g_loss: 0.3040
# Epoch [   17/   40] | d_loss: 0.9699 | g_loss: 1.3742
# Epoch [   18/   40] | d_loss: 2.5328 | g_loss: 0.6195
# Epoch [   18/   40] | d_loss: 0.8446 | g_loss: 2.3024
# Epoch [   18/   40] | d_loss: 0.9473 | g_loss: 1.2358
# Epoch [   18/   40] | d_loss: 0.8576 | g_loss: 1.9982
# Epoch [   18/   40] | d_loss: 0.7211 | g_loss: 1.9446
# Epoch [   18/   40] | d_loss: 0.9112 | g_loss: 1.4205
# Epoch [   19/   40] | d_loss: 0.9069 | g_loss: 1.9023
# Epoch [   19/   40] | d_loss: 0.7433 | g_loss: 1.2268
# Epoch [   19/   40] | d_loss: 0.8724 | g_loss: 1.6156
# Epoch [   19/   40] | d_loss: 1.0669 | g_loss: 1.6842
# Epoch [   19/   40] | d_loss: 0.7834 | g_loss: 2.1033
# Epoch [   19/   40] | d_loss: 0.7498 | g_loss: 1.5121
# Epoch [   20/   40] | d_loss: 0.7514 | g_loss: 1.6788
# Epoch [   20/   40] | d_loss: 0.9019 | g_loss: 1.3007
# Epoch [   20/   40] | d_loss: 0.7892 | g_loss: 1.6868
# Epoch [   20/   40] | d_loss: 0.8070 | g_loss: 1.3112
# Epoch [   20/   40] | d_loss: 0.6793 | g_loss: 1.8995
# Epoch [   20/   40] | d_loss: 0.8603 | g_loss: 2.1729
# Epoch [   21/   40] | d_loss: 0.7251 | g_loss: 2.1513
# Epoch [   21/   40] | d_loss: 1.0228 | g_loss: 0.7618
# Epoch [   21/   40] | d_loss: 1.5772 | g_loss: 0.6507
# Epoch [   21/   40] | d_loss: 0.7436 | g_loss: 1.4272
# Epoch [   21/   40] | d_loss: 1.0228 | g_loss: 0.8554
# Epoch [   21/   40] | d_loss: 0.8400 | g_loss: 1.1120
# Epoch [   22/   40] | d_loss: 0.7572 | g_loss: 2.2839
# Epoch [   22/   40] | d_loss: 0.9940 | g_loss: 0.9252
# Epoch [   22/   40] | d_loss: 0.7917 | g_loss: 2.3821
# Epoch [   22/   40] | d_loss: 0.7841 | g_loss: 2.0645
# Epoch [   22/   40] | d_loss: 0.7417 | g_loss: 1.5634
# Epoch [   22/   40] | d_loss: 0.7695 | g_loss: 1.7739
# Epoch [   23/   40] | d_loss: 0.9374 | g_loss: 2.9493
# Epoch [   23/   40] | d_loss: 0.7409 | g_loss: 1.4941
# Epoch [   23/   40] | d_loss: 2.5194 | g_loss: 3.2733
# Epoch [   23/   40] | d_loss: 0.8037 | g_loss: 2.3331
# Epoch [   23/   40] | d_loss: 0.9101 | g_loss: 0.7576
# Epoch [   23/   40] | d_loss: 0.8314 | g_loss: 1.0777
# Epoch [   24/   40] | d_loss: 0.7459 | g_loss: 1.6431
# Epoch [   24/   40] | d_loss: 0.7558 | g_loss: 2.2006
# Epoch [   24/   40] | d_loss: 0.7565 | g_loss: 2.3563
# Epoch [   24/   40] | d_loss: 0.7444 | g_loss: 2.1358
# Epoch [   24/   40] | d_loss: 2.4042 | g_loss: 0.4685
# Epoch [   24/   40] | d_loss: 0.7254 | g_loss: 1.7705
# Epoch [   25/   40] | d_loss: 0.7118 | g_loss: 2.2344
# Epoch [   25/   40] | d_loss: 0.7752 | g_loss: 1.5195
# Epoch [   25/   40] | d_loss: 1.0438 | g_loss: 0.7961
# Epoch [   25/   40] | d_loss: 0.8427 | g_loss: 1.1650
# Epoch [   25/   40] | d_loss: 0.7289 | g_loss: 1.6090
# Epoch [   25/   40] | d_loss: 0.7800 | g_loss: 1.3947
# Epoch [   26/   40] | d_loss: 0.7519 | g_loss: 2.0635
# Epoch [   26/   40] | d_loss: 0.6810 | g_loss: 1.2549
# Epoch [   26/   40] | d_loss: 0.7649 | g_loss: 2.4140
# Epoch [   26/   40] | d_loss: 0.8000 | g_loss: 1.8686
# Epoch [   26/   40] | d_loss: 0.8579 | g_loss: 2.5855
# Epoch [   26/   40] | d_loss: 0.6592 | g_loss: 1.9823
# Epoch [   27/   40] | d_loss: 0.8916 | g_loss: 2.6898
# Epoch [   27/   40] | d_loss: 0.7337 | g_loss: 2.7516
# Epoch [   27/   40] | d_loss: 0.7571 | g_loss: 2.1493
# Epoch [   27/   40] | d_loss: 0.7816 | g_loss: 2.0130
# Epoch [   27/   40] | d_loss: 1.1619 | g_loss: 0.8551
# Epoch [   27/   40] | d_loss: 0.6867 | g_loss: 1.7520
# Epoch [   28/   40] | d_loss: 1.2702 | g_loss: 3.8239
# Epoch [   28/   40] | d_loss: 0.6759 | g_loss: 1.5791
# Epoch [   28/   40] | d_loss: 0.8725 | g_loss: 0.7219
# Epoch [   28/   40] | d_loss: 0.8205 | g_loss: 1.6131
# Epoch [   28/   40] | d_loss: 0.7095 | g_loss: 2.0843
# Epoch [   28/   40] | d_loss: 0.8312 | g_loss: 1.0730
# Epoch [   29/   40] | d_loss: 1.5315 | g_loss: 3.5177
# Epoch [   29/   40] | d_loss: 0.6648 | g_loss: 1.7687
# Epoch [   29/   40] | d_loss: 0.7239 | g_loss: 1.9211
# Epoch [   29/   40] | d_loss: 0.6865 | g_loss: 1.5909
# Epoch [   29/   40] | d_loss: 0.5678 | g_loss: 1.6833
# Epoch [   29/   40] | d_loss: 0.6380 | g_loss: 1.5097
# Epoch [   30/   40] | d_loss: 0.7212 | g_loss: 2.0918
# Epoch [   30/   40] | d_loss: 0.6900 | g_loss: 1.6255
# Epoch [   30/   40] | d_loss: 0.9058 | g_loss: 0.9932
# Epoch [   30/   40] | d_loss: 0.6445 | g_loss: 2.3863
# Epoch [   30/   40] | d_loss: 0.7122 | g_loss: 1.4347
# Epoch [   30/   40] | d_loss: 0.6614 | g_loss: 2.0687
# Epoch [   31/   40] | d_loss: 0.9412 | g_loss: 0.7294
# Epoch [   31/   40] | d_loss: 0.6450 | g_loss: 1.5054
# Epoch [   31/   40] | d_loss: 0.6105 | g_loss: 1.4900
# Epoch [   31/   40] | d_loss: 0.6614 | g_loss: 2.0365
# Epoch [   31/   40] | d_loss: 0.6274 | g_loss: 1.8705
# Epoch [   31/   40] | d_loss: 0.6594 | g_loss: 1.7787
# Epoch [   32/   40] | d_loss: 0.7990 | g_loss: 3.3933
# Epoch [   32/   40] | d_loss: 0.6360 | g_loss: 1.4743
# Epoch [   32/   40] | d_loss: 0.6912 | g_loss: 1.7348
# Epoch [   32/   40] | d_loss: 0.8232 | g_loss: 2.5864
# Epoch [   32/   40] | d_loss: 0.7012 | g_loss: 2.2903
# Epoch [   32/   40] | d_loss: 0.8349 | g_loss: 2.3821
# Epoch [   33/   40] | d_loss: 0.6180 | g_loss: 1.6154
# Epoch [   33/   40] | d_loss: 0.6471 | g_loss: 1.4736
# Epoch [   33/   40] | d_loss: 1.0324 | g_loss: 1.4829
# Epoch [   33/   40] | d_loss: 0.6001 | g_loss: 2.4721
# Epoch [   33/   40] | d_loss: 0.6561 | g_loss: 1.8026
# Epoch [   33/   40] | d_loss: 0.6823 | g_loss: 2.6926
# Epoch [   34/   40] | d_loss: 1.0951 | g_loss: 1.1467
# Epoch [   34/   40] | d_loss: 0.6671 | g_loss: 2.4696
# Epoch [   34/   40] | d_loss: 0.6610 | g_loss: 1.5182
# Epoch [   34/   40] | d_loss: 0.6113 | g_loss: 2.5348
# Epoch [   34/   40] | d_loss: 0.6938 | g_loss: 2.6885
# Epoch [   34/   40] | d_loss: 0.5491 | g_loss: 2.0062
# Epoch [   35/   40] | d_loss: 0.6819 | g_loss: 2.9176
# Epoch [   35/   40] | d_loss: 0.5600 | g_loss: 1.6607
# Epoch [   35/   40] | d_loss: 0.6226 | g_loss: 1.8753
# Epoch [   35/   40] | d_loss: 0.5834 | g_loss: 2.2830
# Epoch [   35/   40] | d_loss: 0.6745 | g_loss: 1.7115
# Epoch [   35/   40] | d_loss: 0.7900 | g_loss: 3.0361
# Epoch [   36/   40] | d_loss: 0.5365 | g_loss: 1.8248
# Epoch [   36/   40] | d_loss: 1.6199 | g_loss: 0.4666
# Epoch [   36/   40] | d_loss: 0.5858 | g_loss: 2.3928
# Epoch [   36/   40] | d_loss: 0.5944 | g_loss: 1.7909
# Epoch [   36/   40] | d_loss: 0.6158 | g_loss: 2.8417
# Epoch [   36/   40] | d_loss: 0.5996 | g_loss: 2.7765
# Epoch [   37/   40] | d_loss: 0.7618 | g_loss: 1.9932
# Epoch [   37/   40] | d_loss: 1.0102 | g_loss: 3.0976
# Epoch [   37/   40] | d_loss: 0.5874 | g_loss: 2.5015
# Epoch [   37/   40] | d_loss: 0.6935 | g_loss: 1.4708
# Epoch [   37/   40] | d_loss: 0.5866 | g_loss: 1.8190
# Epoch [   37/   40] | d_loss: 0.5793 | g_loss: 1.8797
# Epoch [   38/   40] | d_loss: 0.6315 | g_loss: 1.3203
# Epoch [   38/   40] | d_loss: 0.6566 | g_loss: 3.1656
# Epoch [   38/   40] | d_loss: 0.4790 | g_loss: 2.3724
# Epoch [   38/   40] | d_loss: 0.6021 | g_loss: 1.4928
# Epoch [   38/   40] | d_loss: 1.2780 | g_loss: 4.8898
# Epoch [   38/   40] | d_loss: 0.5634 | g_loss: 2.5155
# Epoch [   39/   40] | d_loss: 0.9557 | g_loss: 0.8262
# Epoch [   39/   40] | d_loss: 0.5719 | g_loss: 2.1615
# Epoch [   39/   40] | d_loss: 0.6587 | g_loss: 2.0079
# Epoch [   39/   40] | d_loss: 0.6177 | g_loss: 3.0353
# Epoch [   39/   40] | d_loss: 0.4884 | g_loss: 2.2445
# Epoch [   39/   40] | d_loss: 0.6637 | g_loss: 3.3154
# Epoch [   40/   40] | d_loss: 0.7382 | g_loss: 3.2422
# Epoch [   40/   40] | d_loss: 0.5279 | g_loss: 2.6036
# Epoch [   40/   40] | d_loss: 0.5221 | g_loss: 2.1467
# Epoch [   40/   40] | d_loss: 0.5525 | g_loss: 1.8505
# Epoch [   40/   40] | d_loss: 0.5498 | g_loss: 2.5164
# Epoch [   40/   40] | d_loss: 1.4433 | g_loss: 0.5241
# C:\Users\ashu\Anaconda3\lib\site-packages\torch\storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255/2).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples1.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)
